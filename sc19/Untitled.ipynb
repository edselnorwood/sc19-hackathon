# %%
import pandas as pd
weather = pd.read_csv('http://chords.tacc.cloud/instruments/16.csv?start=2019-09-26T00:00&end=2019-10-03T25:46', error_bad_lines=False)
weather
# Out:
# b'Skipping line 3: expected 7 fields, saw 8\nSkipping line 12: expected 7 fields, saw 8\nSkipping line 14: expected 7 fields, saw 8\n'
#                                                                         # dataset: GeoCSV 2.0
# # field_unit: ISO_8601 rpm                  hz  mph  rain  humidity  C              direction
# # attribution: chords.tacc.cloud           NaN NaN  NaN   NaN       NaN                   NaN
# # delimiter:                               NaN NaN  NaN   NaN       NaN                   NaN
# # device_information: tacc-weatherstation  NaN NaN  NaN   NaN       NaN                   NaN
# # creation_date: 2019-11-19 16:19:48 +0000 NaN NaN  NaN   NaN       NaN                   NaN
# # data collection site: TACC               NaN NaN  NaN   NaN       NaN                   NaN
# # data collection longitude: -97.725412    NaN NaN  NaN   NaN       NaN                   NaN
# # data collection latitude: 30.390182      NaN NaN  NaN   NaN       NaN                   NaN
# # data collection elevation: 0.0 meters    NaN NaN  NaN   NaN       NaN                   NaN
# # Measurements in File: 0                  NaN NaN  NaN   NaN       NaN                   NaN

# %%
import pandas as pd 
import numpy as np 
import requests
import csv
import matplotlib.pyplot as plt

def get_data(url, filename):
    r = requests.get(url)
    decoded_re = decode(r)
    cr = to_csv(decoded_re)
    data_list = csv_to_list(cr)
    headers = get_headers(data_list)
    datatree_ready = create_datatree(data_list, headers)
    datatree_ready.describe()
    print(datalist)

def decode(re, format="utf"):
    return (re.content.decode(format))

def to_csv(decoded_re):
    return (csv.reader(decoded_re.splitlines(), delimiter=","))

def csv_to_list(cr):
    data_list = list(cr)
    return (data_list)

def get_headers(data_list):
    headers = data_list[13]
    return (headers)

def create_datatree(data_list, headers):
    datatree_data = pd.DataFrame(data_list)
    datatree_data.columns = headers
    datatree_data.set_index("Time")
    datatree_ready = datatree_data.iloc[14:]
    datatree_ready.set_index("Time")
    return (datatree_ready)

# %%
import chord_get

print (chord_get.get_data("http://chords.tacc.cloud/instruments/16.csv?last", "datatree_test5.csv"))
# Out:
#                         Time wind_rpm wind_hz wind_mph rain_gauge  \
# count                      1        1       1        1          1
# unique                     1        1       1        1          1
# top     2019-10-03T06:25:46Z        0       0        0          0
# freq                       1        1       1        1          1
#
#             humidity         temp wind_direction
# count              1            1              1
# unique             1            1              1
# top     -4.828887939  25.85543633           1141
# freq               1            1              1
# None
